# %%
from IPython.display import Image
from IPython.core.display import HTML
import numpy as np
import random
from scipy.integrate import RK45
import matplotlib.pyplot as plt
from fanchart.plot import *

# %%
#  Zadanie 7
Image(url= "./List2_images/Zadanie7_tresc.png")

# %%
# Wykres dla SI

# parametry
beta = .5
gamma = .1
N = 1000
T = 10000
dt = 1 # krok czasowy na wykresie - nie ma wpływu na dokładność rozwiązania  
steps = int(T / dt)
T_ode = np.zeros(N)
s_i = lambda t, s, i:  ((-beta * i * s )/ N)
i_i = lambda t, s, i:  beta * i * s / N
arr_S = []
arr_I = []
for num in range(100):
    S = np.zeros(T)
    I = np.zeros(T)
    S[0] = N-100
    I[0] = 100
    N_arr = np.linspace(1,10000,10000)

    u1 = np.random.rand(T)
    u2 = np.random.rand(T)

    # for x in range(N-1):
    #     S[x+1] = S[x] + dt*s_i(T_ode[x], S[x], I[x])
    #     I[x+1] = I[x] + dt*i_i(T_ode[x], S[x], I[x])
    for x in range(T-1):
        # print(beta*I[x]*S[x]/T**2)
        if u1[x]<beta*I[x]*S[x]/N**2:
            # print(x)
            S[x+1] = S[x] - 1
            I[x+1] = I[x] + 1
        else:
            S[x+1] = S[x]
            I[x+1] = I[x]
    arr_S.append(S)
    arr_I.append(I)
fig, ax = plt.subplots()
ones = np.ones(100)
i=0
for s in arr_S:
    x = np.linspace(0,len(s),len(s))
    alpha = 0.5*(i+1)/len(s)
    ax.fill_between(x, s, s, color='red', alpha=alpha)
    i+=1
ax.plot(x, s, color='red')
plt.show()

# %%
# parametry
beta = .5
gamma = .1
N = 1000
T = 10000
dt = 1 # krok czasowy na wykresie - nie ma wpływu na dokładność rozwiązania  
steps = int(T / dt)
T_ode = np.zeros(N)
s_i = lambda t, s, i:  ((-beta * i * s )/ N)
i_i = lambda t, s, i:  beta * i * s / N
arr_S = []
arr_I = []
for num in range(100):
    S = np.zeros(T)
    I = np.zeros(T)
    S[0] = N-100
    I[0] = 100
    N_arr = np.linspace(1,10000,10000)

    u1 = np.random.rand(T)
    u2 = np.random.rand(T)

    # for x in range(N-1):
    #     S[x+1] = S[x] + dt*s_i(T_ode[x], S[x], I[x])
    #     I[x+1] = I[x] + dt*i_i(T_ode[x], S[x], I[x])
    for x in range(T-1):
        # print(beta*I[x]*S[x]/T**2)
        if u1[x]<beta*I[x]*S[x]/N**2:
            # print(x)
            S[x+1] = S[x] - 1
            I[x+1] = I[x] + 1
        else:
            S[x+1] = S[x]
            I[x+1] = I[x]
    arr_S.append(S)
    arr_I.append(I)

plt.figure(1)
x = np.linspace(0,len(arr_S[0]),len(arr_S[0]))
i=0
for s in arr_S:
    plt.plot(x,s,color='gray')
arr_S=np.array(arr_S)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_S,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SI")
plt.ylabel("Wartość populacji dla S")
plt.xlabel("Czas np. dni")
plt.show()

plt.figure(2)
x = np.linspace(0,len(arr_I[0]),len(arr_I[0]))
i=0
for s in arr_I:
    plt.plot(x,s,color='gray')
arr_I=np.array(arr_I)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_I,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SI")
plt.ylabel("Wartość populacji dla I")
plt.xlabel("Czas np. dni")
plt.show()

# %%
# SIS
# parametry
beta = .5
gamma = .1
N = 1000
T = 100000
dt = 1 # krok czasowy na wykresie - nie ma wpływu na dokładność rozwiązania  
steps = int(T / dt)
T_ode = np.zeros(N)
s_i = lambda t, s, i:  -beta * i * s / N + gamma * i
i_i = lambda t, s, i:  beta * i * s / N - gamma * i

arr_S = []
arr_I = []
for num in range(100):
    S = np.zeros(T)
    I = np.zeros(T)
    S[0] = N-100
    I[0] = 100
    N_arr = np.linspace(0,T,T)

    u1 = np.random.rand(T)
    u2 = np.random.rand(T)

    for x in range(T-1):
        if u1[x]<beta*I[x]*S[x]/N**2:
            S[x+1] = S[x] - 1
            I[x+1] = I[x] + 1
        else:
            S[x+1] = S[x]
            I[x+1] = I[x] 

        if u2[x]<gamma * I[x]/N:
            S[x+1] = S[x] + 1
            I[x+1] = I[x] - 1
    arr_S.append(S)
    arr_I.append(I)

plt.figure(1)
x = np.linspace(0,len(arr_S[0]),len(arr_S[0]))
i=0
for s in arr_S:
    plt.plot(x,s,color='gray')
arr_S=np.array(arr_S)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_S,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SIS")
plt.ylabel("Wartość populacji dla S")
plt.xlabel("Czas np. dni")
plt.show()

plt.figure(2)
x = np.linspace(0,len(arr_I[0]),len(arr_I[0]))
i=0
for s in arr_I:
    plt.plot(x,s,color='gray')
arr_I=np.array(arr_I)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_I,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SIS")
plt.ylabel("Wartość populacji dla I")
plt.xlabel("Czas np. dni")
plt.show()

# %%
# parametry
beta = .5
eta = .1
gamma = .1
N = 1000
T = 20000

arr_S = []
arr_I = []
arr_R = []

dt = 1 # krok czasowy na wykresie - nie ma wpływu na dokładność rozwiązania  
steps = int(T / dt)
T_ode = np.zeros(N)
for num in range(100):
    S = np.zeros(T)
    I = np.zeros(T)
    R = np.zeros(T)
    S[0] = N-200
    I[0] = 100
    R[0] = 100
    N_arr = np.linspace(0,T,T)

    u1 = np.random.rand(T)
    u2 = np.random.rand(T)
    u3 = np.random.rand(T)

    for x in range(T-1):
        if u1[x]<beta*I[x]*S[x]/N**2:
            S[x+1] = S[x] - 1
            I[x+1] = I[x] + 1
        else:
            S[x+1] = S[x]
            I[x+1] = I[x] 
        if u2[x]<gamma * I[x]/N:
            R[x+1] = R[x] + 1
            I[x+1] = I[x] - 1
        else:
            R[x+1] = R[x]
        if u3[x]<eta*R[x]/N:
            R[x+1] = R[x] - 1
            S[x+1] = S[x] + 1
    arr_S.append(S)
    arr_I.append(I)
    arr_R.append(R)
plt.figure(1)
x = np.linspace(0,len(arr_S[0]),len(arr_S[0]))
i=0
for s in arr_S:
    plt.plot(x,s,color='gray')
arr_S=np.array(arr_S)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_S,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SEIR")
plt.ylabel("Wartość populacji dla S")
plt.xlabel("Czas np. dni")
plt.savefig('Zad7_c_S.png', dpi=300)
plt.show()

plt.figure(2)
x = np.linspace(0,len(arr_I[0]),len(arr_I[0]))
i=0
for s in arr_I:
    plt.plot(x,s,color='gray')
arr_I=np.array(arr_I)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_I,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SIRS")
plt.ylabel("Wartość populacji dla I")
plt.xlabel("Czas np. dni")
plt.savefig('Zad7_c_I.png', dpi=300)
plt.show()

plt.figure(3)
x = np.linspace(0,len(arr_R[0]),len(arr_R[0]))
i=0
for s in arr_R:
    plt.plot(x,s,color='gray')
arr_R=np.array(arr_R)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_R,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SIRS")
plt.ylabel("Wartość populacji dla R")
plt.xlabel("Czas np. dni")
plt.savefig('Zad7_c_R.png', dpi=300)
plt.show()

# %%
#  Zadanie 8
Image(url= "./List2_images/Zadanie8_tresc.png")

# %%
# Podpunkt (d) model SEIR dla metody Eulera

# parametry
beta = .5
gamma = .1
eta = .1
sigma = .1
N = 1000
T = 20000

arr_S = []
arr_I = []
arr_R = []
arr_E = []

for num in range(100):
    S = np.zeros(T)
    I = np.zeros(T)
    R = np.zeros(T)
    E = np.zeros(T)
    T_ode = np.zeros(T)
    S[0] = N-301
    I[0] = 200
    R[0] = 1
    E[0] = 100
    N_arr = np.linspace(1,T,T)

    u1 = np.random.rand(T)
    u2 = np.random.rand(T)
    u3 = np.random.rand(T)

    dt = 1 # krok czasowy na wykresie - nie ma wpływu na dokładność rozwiązania  
    steps = int(T / dt)
    for x in range(T-1):
        if u1[x]<beta*I[x]*S[x]/N**2:
            S[x+1] = S[x] - 1
            E[x+1] = E[x] + 1
        else:
            S[x+1] = S[x]
            E[x+1] = E[x]
        if u2[x]<sigma*E[x]/N:
            E[x+1] = E[x] - 1
            I[x+1] = I[x] + 1
        else:
            I[x+1] = I[x]
        if u3[x]<gamma*I[x]/N:
            R[x+1] = R[x] + 1
            I[x+1] = I[x] - 1
        else:
            R[x+1] = R[x]
    arr_S.append(S)
    arr_I.append(I)
    arr_R.append(R)
    arr_E.append(E)
plt.figure(1)
x = np.linspace(0,len(arr_S[0]),len(arr_S[0]))
i=0
for s in arr_S:
    plt.plot(x,s,color='gray')
arr_S=np.array(arr_S)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_S,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SEIR")
plt.ylabel("Wartość populacji dla S")
plt.xlabel("Czas np. dni")
plt.savefig('Zad8_a_S.png', dpi=300)
plt.show()

plt.figure(2)
x = np.linspace(0,len(arr_I[0]),len(arr_I[0]))
i=0
for s in arr_I:
    plt.plot(x,s,color='gray')
arr_R=np.array(arr_R)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_I,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SEIR")
plt.ylabel("Wartość populacji dla I")
plt.xlabel("Czas np. dni")
plt.savefig('Zad8_a_I.png', dpi=300)
plt.show()

plt.figure(4)
x = np.linspace(0,len(arr_E[0]),len(arr_E[0]))
i=0
for s in arr_E:
    plt.plot(x,s,color='gray')
arr_E=np.array(arr_E)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_E,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SEIR")
plt.ylabel("Wartość populacji dla E")
plt.xlabel("Czas np. dni")
plt.savefig('Zad8_a_E.png', dpi=300)
plt.show()

plt.figure(3)
x = np.linspace(0,len(arr_R[0]),len(arr_R[0]))
i=0
for s in arr_R:
    plt.plot(x,s,color='gray')
arr_I=np.array(arr_I)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_R,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SEIR")
plt.ylabel("Wartość populacji dla R")
plt.xlabel("Czas np. dni")
plt.savefig('Zad8_a_R.png', dpi=300)
plt.show()

# %%
# Podpunkt (d) model SEIR dla metody Eulera

# parametry
beta = .5
gamma = .1
eta = .1
sigma = .1
N = 1000
T = 20000

arr_S = []
arr_I = []
arr_R = []
arr_E = []

for num in range(100):
    S = np.zeros(T)
    I = np.zeros(T)
    R = np.zeros(T)
    E = np.zeros(T)
    T_ode = np.zeros(T)
    S[0] = N-301
    I[0] = 200
    R[0] = 1
    E[0] = 100
    N_arr = np.linspace(1,T,T)

    u1 = np.random.rand(T)
    u2 = np.random.rand(T)
    u3 = np.random.rand(T)
    u4 = np.random.rand(T)

    dt = 1 # krok czasowy na wykresie - nie ma wpływu na dokładność rozwiązania  
    steps = int(T / dt)
    for x in range(T-1):
        if u1[x]<beta*I[x]*S[x]/N**2:
            S[x+1] = S[x] - 1
            E[x+1] = E[x] + 1
        else:
            S[x+1] = S[x]
            E[x+1] = E[x]
        if u2[x]<sigma*E[x]/N:
            E[x+1] = E[x] - 1
            I[x+1] = I[x] + 1
        else:
            I[x+1] = I[x]
        if u3[x]<gamma*I[x]/N:
            R[x+1] = R[x] + 1
            I[x+1] = I[x] - 1
        else:
            R[x+1] = R[x]
        if u4[x]<eta*R[x]/N:
            R[x+1] = R[x] - 1
            S[x+1] = S[x] + 1
    arr_S.append(S)
    arr_I.append(I)
    arr_R.append(R)
    arr_E.append(E)
plt.figure(1)
x = np.linspace(0,len(arr_S[0]),len(arr_S[0]))
i=0
for s in arr_S:
    plt.plot(x,s,color='gray')
arr_S=np.array(arr_S)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_S,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SEIRS")
plt.ylabel("Wartość populacji dla S")
plt.xlabel("Czas np. dni")
plt.savefig('Zad8_b_S.png', dpi=300)
plt.show()

plt.figure(2)
x = np.linspace(0,len(arr_I[0]),len(arr_I[0]))
i=0
for s in arr_I:
    plt.plot(x,s,color='gray')
arr_R=np.array(arr_R)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_I,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SEIRS")
plt.ylabel("Wartość populacji dla I")
plt.xlabel("Czas np. dni")
plt.savefig('Zad8_b_I.png', dpi=300)
plt.show()

plt.figure(4)
x = np.linspace(0,len(arr_E[0]),len(arr_E[0]))
i=0
for s in arr_E:
    plt.plot(x,s,color='gray')
arr_E=np.array(arr_E)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_E,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SEIRS")
plt.ylabel("Wartość populacji dla E")
plt.xlabel("Czas np. dni")
plt.savefig('Zad8_b_E.png', dpi=300)
plt.show()

plt.figure(3)
x = np.linspace(0,len(arr_R[0]),len(arr_R[0]))
i=0
for s in arr_R:
    plt.plot(x,s,color='gray')
arr_I=np.array(arr_I)
col = ['red','yellow','blue','aqua','green','cyan','magenta','black','tan','brown']
for kwan in range(1,10,1):
    i=kwan
    kwan=kwan/10
    qwant = np.quantile(arr_R,kwan,keepdims=True,axis=0)
    plt.plot(x,qwant[0,:],label=f'Kwantyl={kwan}',color = col[i])
plt.legend()
plt.title("Linie kwantylowe dla modeli SEIRS")
plt.ylabel("Wartość populacji dla R")
plt.xlabel("Czas np. dni")
plt.savefig('Zad8_b_R.png', dpi=300)
plt.show()
